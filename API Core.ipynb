# %% [markdown]
# # Efficient Yelp API calls

# %%
# Load imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from yelpapi import YelpAPI
import os, json, math, time
from tqdm.notebook import tqdm_notebook

# %%
# Import JSON and API credentials
import json
with open('/Users/ridge/.secret/yelp_api.json','r') as f: 
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
# Instantiate API variable
yelp_api = YelpAPI(login['api-key'], timeout_s=5.0)
yelp_api

# %%
# Set API call parameters
location = 'Durant, OK 74701'
term = 'burrito'

# %%
location.split(',')[0]
# Out:
# 'Durant'

# %%
# Create save folder
STORAGE = 'Data/'

os.makedirs(STORAGE, exist_ok = True)
JSON_FILE = STORAGE+f"{location.split(',')[0]}-{term}.json"

# %%
JSON_FILE
# Out:
# 'Data/Durant-burrito.json'

# %%
#### Check to see if file exists

file_exists = os.path.isfile(JSON_FILE)

if file_exists == False:
    folder = os.path.dirname(JSON_FILE)
    if len(folder)>0:
        os.makedirs(folder, exist_ok = True)
        print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
        with open(JSON_FILE, 'w') as f:
              json.dump([], f)
              
else:
    print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/Durant-burrito.json not found. Saving empty list to file.

# %%
# Create search query
results = yelp_api.search_query(term = term, location = location)

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['total']
# Out:
# 16

# %%
results['region']
# Out:
# {'center': {'longitude': -96.39335632324219, 'latitude': 34.01107649677313}}

# %%
results['businesses']
# Out:
# [{'id': 'E1p7DsTVgbuKffugEhPPsw',
#   'alias': 'tacos-locos-durant',
#   'name': 'Tacos Locos',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/s0sjTNoqUXRB4ENap8AO5w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tacos-locos-durant?adjust_creative=1xW5JRMOWdnu8rnI6sXJjQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1xW5JRMOWdnu8rnI6sXJjQ',
#   'review_count': 20,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 34.0064621463552,
#    'longitude': -96.3913196257154},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '1255 N Washington Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Durant',
#    'zip_code': '74701',
#    'country': 'US',
#    'state': 'OK',
#    'display_address': ['1255 N Washington Ave', 'Durant, OK 74701']},
#   'phone': '+15807458114',
#   'display_phone': '(580) 745-8114',
#   'distance': 546.3577813800408},
#  {'id': 't7i3ZNJDKoGxSRxTXSK0eQ',
#   'alias': 'villegas-meat-market-durant-2',
#   'name': 'Villegas Meat Market',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Nc0CQJvXwgdZJm27UKhNsA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/villegas-meat-market-durant-2?adjust_creative=1xW5JRMOWdnu8rnI6sXJjQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1xW5JRMOWdnu8rnI6sXJjQ',
#   'review_count': 118,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'tex-mex', 'title': 'Tex-Mex'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 33.9877463, 'longitude': -96.3868511},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '510 S 9th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Durant',
#    'zip_code': '74701',
#    'country': 'US',
#    'state': 'OK',
#    'display_address': ['510 S 9th Ave', 'Durant, OK 74701']},
#   'phone': '+15809200915',
#   'display_phone': '(580) 920-0915',
#   'distance': 2656.9267807281412},
#  {'id': 'xUTVaqLxdvde-hWbnJisTg',
#   'alias': 'el-kanelo-mexican-restaurant-durant',
#   'name': 'El Kanelo Mexican Restaurant',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4ZvsfTMx68QFyLZ-dirA3w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/el-kanelo-mexican-restaurant-durant?adjust_creative=1xW5JRMOWdnu8rnI6sXJjQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1xW5JRMOWdnu8rnI6sXJjQ',
#   'review_count': 28,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 33.9969991, 'longitude': -96.3743164},
#   'transactions': [],
#   'location': {'address1': '729 N 1st St',
#    'address2': None,
#    'address3': '',
#    'city': 'Durant',
#    'zip_code': '74701',
#    'country': 'US',
#    'state': 'OK',
#    'display_address': ['729 N 1st St', 'Durant, OK 74701']},
#   'phone': '+15807458034',
#   'display_phone': '(580) 745-8034',
#   'distance': 2310.700387117841},
#  {'id': 'yB3iioJpVxvZMcd9LXd4jA',
#   'alias': 'taco-mayo-durant',
#   'name': 'Taco Mayo',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ig9NiaX4WikPuGHJb3B8zA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/taco-mayo-durant?adjust_creative=1xW5JRMOWdnu8rnI6sXJjQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1xW5JRMOWdnu8rnI6sXJjQ',
#   'review_count': 7,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 34.0011516015915,
#    'longitude': -96.4098322885096},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '420 University Pl',
#    'address2': '',
#    'address3': '',
#    'city': 'Durant',
#    'zip_code': '74701',
#    'country': 'US',
#    'state': 'OK',
#    'display_address': ['420 University Pl', 'Durant, OK 74701']},
#   'phone': '+15809200162',
#   'display_phone': '(580) 920-0162',
#   'distance': 1877.3498846772825},
#  {'id': 'Slg2y3fjTSNiKwvUuUh4WA',
#   'alias': 'taco-casa-durant',
#   'name': 'Taco Casa',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5qnsJ0lIfAjb40RPDt8JMA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/taco-casa-durant?adjust_creative=1xW5JRMOWdnu8rnI6sXJjQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1xW5JRMOWdnu8rnI6sXJjQ',
#   'review_count': 13,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 33.993478579514935,
#    'longitude': -96.37515342928161},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '324 N 1st Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Durant',
#    'zip_code': '74701',
#    'country': 'US',
#    'state': 'OK',
#    'display_address': ['324 N 1st Ave', 'Durant, OK 74701']},
#   'phone': '+15809202820',
#   'display_phone': '(580) 920-2820',
#   'distance': 2577.727766207811},
#  {'id': 'AK25Wi19dM4XCUCsxJpOQg',
#   'alias': 'salitas-durant',
#   'name': "Salita's",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mdGtHMhCZZOJMztc2uOKlA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/salitas-durant?adjust_creative=1xW5JRMOWdnu8rnI6sXJjQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1xW5JRMOWdnu8rnI6sXJjQ',
#   'review_count': 64,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'tex-mex', 'title': 'Tex-Mex'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 33.9943084716797,
#    'longitude': -96.3891143798828},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1202 W Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Durant',
#    'zip_code': '74701',
#    'country': 'US',
#    'state': 'OK',
#    'display_address': ['1202 W Main St', 'Durant, OK 74701']},
#   'phone': '+15809242945',
#   'display_phone': '(580) 924-2945',
#   'distance': 1898.9959155325414},
#  {'id': 'aE6v2LqAL7icH240cs1nYA',
#   'alias': 'taco-mayo-durant-2',
#   'name': 'Taco Mayo',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3apK_8Yp_blQLK1eqaUpSg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/taco-mayo-durant-2?adjust_creative=1xW5JRMOWdnu8rnI6sXJjQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1xW5JRMOWdnu8rnI6sXJjQ',
#   'review_count': 1,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 33.9988284, 'longitude': -96.4073056},
#   'transactions': [],
#   'location': {'address1': '2430 W Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Durant',
#    'zip_code': '74701',
#    'country': 'US',
#    'state': 'OK',
#    'display_address': ['2430 W Main St', 'Durant, OK 74701']},
#   'phone': '+15809200162',
#   'display_phone': '(580) 920-0162',
#   'distance': 1849.4157291703182},
#  {'id': 'kf0SxbAdO8PeQeDqNtAbvg',
#   'alias': 'taco-bell-durant',
#   'name': 'Taco Bell',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tuuFSVJVUXFV7x0ApLQ8uQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/taco-bell-durant?adjust_creative=1xW5JRMOWdnu8rnI6sXJjQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1xW5JRMOWdnu8rnI6sXJjQ',
#   'review_count': 20,
#   'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 2.0,
#   'coordinates': {'latitude': 33.99947, 'longitude': -96.40599},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '206 Westside Dr',
#    'address2': '',
#    'address3': '',
#    'city': 'Durant',
#    'zip_code': '74701',
#    'country': 'US',
#    'state': 'OK',
#    'display_address': ['206 Westside Dr', 'Durant, OK 74701']},
#   'phone': '+15809200242',
#   'display_phone': '(580) 920-0242',
#   'distance': 1738.3325097822242},
#  {'id': 'GIqv_6V4RGHz1b2624zN6Q',
#   'alias': 'taco-casa-calera',
#   'name': 'Taco Casa',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zgTdwjxL7oO-j_Wywxzl-g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/taco-casa-calera?adjust_creative=1xW5JRMOWdnu8rnI6sXJjQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1xW5JRMOWdnu8rnI6sXJjQ',
#   'review_count': 9,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 33.9384640511098, 'longitude': -96.422974821476},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '703 S Service Rd',
#    'address2': None,
#    'address3': None,
#    'city': 'Calera',
#    'zip_code': '74730',
#    'country': 'US',
#    'state': 'OK',
#    'display_address': ['703 S Service Rd', 'Calera, OK 74730']},
#   'phone': '+15804344090',
#   'display_phone': '(580) 434-4090',
#   'distance': 8523.548218974822},
#  {'id': 'ivd0oHXDMvuBZfXj8eGGOA',
#   'alias': 'munchies-donuts-and-brunch-durant',
#   'name': 'Munchies Donuts & Brunch',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dEDSVM8sBp1USewEHyGHmg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/munchies-donuts-and-brunch-durant?adjust_creative=1xW5JRMOWdnu8rnI6sXJjQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1xW5JRMOWdnu8rnI6sXJjQ',
#   'review_count': 8,
#   'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 34.0056807, 'longitude': -96.4054786},
#   'transactions': [],
#   'location': {'address1': '2836 W University Blvd',
#    'address2': 'Ste 126',
#    'address3': '',
#    'city': 'Durant',
#    'zip_code': '74701',
#    'country': 'US',
#    'state': 'OK',
#    'display_address': ['2836 W University Blvd',
#     'Ste 126',
#     'Durant, OK 74701']},
#   'phone': '+15809209190',
#   'display_phone': '(580) 920-9190',
#   'distance': 1268.2723348741758},
#  {'id': 'UpjcgygjhDoQUj9RCnzSJA',
#   'alias': 'jimmys-egg-durant',
#   'name': "Jimmy's Egg",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/b2BcWT8FYGZ2V2OF3v7DiA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/jimmys-egg-durant?adjust_creative=1xW5JRMOWdnu8rnI6sXJjQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1xW5JRMOWdnu8rnI6sXJjQ',
#   'review_count': 59,
#   'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 33.998253, 'longitude': -96.409073},
#   'transactions': ['pickup'],
#   'price': '$$',
#   'location': {'address1': '2501 W Main St',
#    'address2': '',
#    'address3': None,
#    'city': 'Durant',
#    'zip_code': '74701',
#    'country': 'US',
#    'state': 'OK',
#    'display_address': ['2501 W Main St', 'Durant, OK 74701']},
#   'phone': '+15809201777',
#   'display_phone': '(580) 920-1777',
#   'distance': 2032.758120246741},
#  {'id': 'F4wLxJwl8v_RY4s_aLRjtQ',
#   'alias': 'jalapenos-mexican-restaurant-durant',
#   'name': 'Jalapenos Mexican Restaurant',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/roapgSuGNj3mQeDsqL-EmQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/jalapenos-mexican-restaurant-durant?adjust_creative=1xW5JRMOWdnu8rnI6sXJjQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1xW5JRMOWdnu8rnI6sXJjQ',
#   'review_count': 58,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 33.9988187, 'longitude': -96.373228},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '902 N 1st Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Durant',
#    'zip_code': '74701',
#    'country': 'US',
#    'state': 'OK',
#    'display_address': ['902 N 1st Ave', 'Durant, OK 74701']},
#   'phone': '+15809201526',
#   'display_phone': '(580) 920-1526',
#   'distance': 2302.247131056382},
#  {'id': 'HpSMHSad8t1PeDT0qoPoJA',
#   'alias': 'grand-cafe-durant',
#   'name': 'Grand Cafe',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/szEgNWw_nIm6JBHrU0jPxg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/grand-cafe-durant?adjust_creative=1xW5JRMOWdnu8rnI6sXJjQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1xW5JRMOWdnu8rnI6sXJjQ',
#   'review_count': 30,
#   'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 33.951446, 'longitude': -96.413891},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '4216 S Hwy 69/75',
#    'address2': '',
#    'address3': None,
#    'city': 'Durant',
#    'zip_code': '74701',
#    'country': 'US',
#    'state': 'OK',
#    'display_address': ['4216 S Hwy 69/75', 'Durant, OK 74701']},
#   'phone': '+15809200160',
#   'display_phone': '(580) 920-0160',
#   'distance': 2103.521274018166},
#  {'id': 'NGtKhl_IFFj23rSI5ouBLQ',
#   'alias': 'sonic-drive-in-durant',
#   'name': 'Sonic Drive-In',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/O2OdcrVDYOq-W_TjVv8Uxg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sonic-drive-in-durant?adjust_creative=1xW5JRMOWdnu8rnI6sXJjQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1xW5JRMOWdnu8rnI6sXJjQ',
#   'review_count': 8,
#   'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#   'rating': 2.0,
#   'coordinates': {'latitude': 34.00110134174037,
#    'longitude': -96.37311310548782},
#   'transactions': [],
#   'location': {'address1': '1111 N First St',
#    'address2': '',
#    'address3': '',
#    'city': 'Durant',
#    'zip_code': '74701',
#    'country': 'US',
#    'state': 'OK',
#    'display_address': ['1111 N First St', 'Durant, OK 74701']},
#   'phone': '+15809245050',
#   'display_phone': '(580) 924-5050',
#   'distance': 2170.7546401910768},
#  {'id': 'VNzpX2V9726J1UGmrkzfQA',
#   'alias': 'sonic-drive-in-durant-5',
#   'name': 'Sonic Drive-In',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/clHW-XBkyWvV_YOmQGbEPA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sonic-drive-in-durant-5?adjust_creative=1xW5JRMOWdnu8rnI6sXJjQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1xW5JRMOWdnu8rnI6sXJjQ',
#   'review_count': 16,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#   'rating': 2.0,
#   'coordinates': {'latitude': 33.9986944529491,
#    'longitude': -96.4119849392091},
#   'transactions': [],
#   'location': {'address1': '3619 West Main St',
#    'address2': None,
#    'address3': None,
#    'city': 'Durant',
#    'zip_code': '74701',
#    'country': 'US',
#    'state': 'OK',
#    'display_address': ['3619 West Main St', 'Durant, OK 74701']},
#   'phone': '+15809202206',
#   'display_phone': '(580) 920-2206',
#   'distance': 2200.9809188524678},
#  {'id': 'V_C-EJdiz71IPzgGZC5mSA',
#   'alias': 'sonic-drive-in-calera',
#   'name': 'Sonic Drive-In',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cHNLdHworTxcvjofP45R6g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sonic-drive-in-calera?adjust_creative=1xW5JRMOWdnu8rnI6sXJjQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=1xW5JRMOWdnu8rnI6sXJjQ',
#   'review_count': 16,
#   'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#   'rating': 1.5,
#   'coordinates': {'latitude': 33.9388265, 'longitude': -96.4226701},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '713 N Service Rd',
#    'address2': None,
#    'address3': None,
#    'city': 'Calera',
#    'zip_code': '74730',
#    'country': 'US',
#    'state': 'OK',
#    'display_address': ['713 N Service Rd', 'Calera, OK 74730']},
#   'phone': '+15809317777',
#   'display_phone': '(580) 931-7777',
#   'distance': 8476.37635990869}]

# %%
# Convert results to dataframe
pd.DataFrame(results['businesses'])
# Out:
#                         id                                alias  \
# 0   E1p7DsTVgbuKffugEhPPsw                   tacos-locos-durant
# 1   t7i3ZNJDKoGxSRxTXSK0eQ        villegas-meat-market-durant-2
# 2   xUTVaqLxdvde-hWbnJisTg  el-kanelo-mexican-restaurant-durant
# 3   yB3iioJpVxvZMcd9LXd4jA                     taco-mayo-durant
# 4   Slg2y3fjTSNiKwvUuUh4WA                     taco-casa-durant
# 5   AK25Wi19dM4XCUCsxJpOQg                       salitas-durant
# 6   aE6v2LqAL7icH240cs1nYA                   taco-mayo-durant-2
# 7   kf0SxbAdO8PeQeDqNtAbvg                     taco-bell-durant
# 8   GIqv_6V4RGHz1b2624zN6Q                     taco-casa-calera
# 9   ivd0oHXDMvuBZfXj8eGGOA    munchies-donuts-and-brunch-durant
# 10  UpjcgygjhDoQUj9RCnzSJA                    jimmys-egg-durant
# 11  F4wLxJwl8v_RY4s_aLRjtQ  jalapenos-mexican-restaurant-durant
# 12  HpSMHSad8t1PeDT0qoPoJA                    grand-cafe-durant
# 13  NGtKhl_IFFj23rSI5ouBLQ                sonic-drive-in-durant
# 14  VNzpX2V9726J1UGmrkzfQA              sonic-drive-in-durant-5
# 15  V_C-EJdiz71IPzgGZC5mSA                sonic-drive-in-calera
#
#                             name  \
# 0                    Tacos Locos
# 1           Villegas Meat Market
# 2   El Kanelo Mexican Restaurant
# 3                      Taco Mayo
# 4                      Taco Casa
# 5                       Salita's
# 6                      Taco Mayo
# 7                      Taco Bell
# 8                      Taco Casa
# 9       Munchies Donuts & Brunch
# 10                   Jimmy's Egg
# 11  Jalapenos Mexican Restaurant
# 12                    Grand Cafe
# 13                Sonic Drive-In
# 14                Sonic Drive-In
# 15                Sonic Drive-In
#
#                                             image_url  is_closed  \
# 0   https://s3-media4.fl.yelpcdn.com/bphoto/s0sjTN...      False
# 1   https://s3-media2.fl.yelpcdn.com/bphoto/Nc0CQJ...      False
# 2   https://s3-media1.fl.yelpcdn.com/bphoto/4ZvsfT...      False
# 3   https://s3-media1.fl.yelpcdn.com/bphoto/Ig9Nia...      False
# 4   https://s3-media3.fl.yelpcdn.com/bphoto/5qnsJ0...      False
# 5   https://s3-media2.fl.yelpcdn.com/bphoto/mdGtHM...      False
# 6   https://s3-media4.fl.yelpcdn.com/bphoto/3apK_8...      False
# 7   https://s3-media2.fl.yelpcdn.com/bphoto/tuuFSV...      False
# 8   https://s3-media1.fl.yelpcdn.com/bphoto/zgTdwj...      False
# 9   https://s3-media3.fl.yelpcdn.com/bphoto/dEDSVM...      False
# 10  https://s3-media4.fl.yelpcdn.com/bphoto/b2BcWT...      False
# 11  https://s3-media3.fl.yelpcdn.com/bphoto/roapgS...      False
# 12  https://s3-media3.fl.yelpcdn.com/bphoto/szEgNW...      False
# 13  https://s3-media4.fl.yelpcdn.com/bphoto/O2Odcr...      False
# 14  https://s3-media1.fl.yelpcdn.com/bphoto/clHW-X...      False
# 15  https://s3-media1.fl.yelpcdn.com/bphoto/cHNLdH...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/tacos-locos-durant?ad...            20
# 1   https://www.yelp.com/biz/villegas-meat-market-...           118
# 2   https://www.yelp.com/biz/el-kanelo-mexican-res...            28
# 3   https://www.yelp.com/biz/taco-mayo-durant?adju...             7
# 4   https://www.yelp.com/biz/taco-casa-durant?adju...            13
# 5   https://www.yelp.com/biz/salitas-durant?adjust...            64
# 6   https://www.yelp.com/biz/taco-mayo-durant-2?ad...             1
# 7   https://www.yelp.com/biz/taco-bell-durant?adju...            20
# 8   https://www.yelp.com/biz/taco-casa-calera?adju...             9
# 9   https://www.yelp.com/biz/munchies-donuts-and-b...             8
# 10  https://www.yelp.com/biz/jimmys-egg-durant?adj...            59
# 11  https://www.yelp.com/biz/jalapenos-mexican-res...            58
# 12  https://www.yelp.com/biz/grand-cafe-durant?adj...            30
# 13  https://www.yelp.com/biz/sonic-drive-in-durant...             8
# 14  https://www.yelp.com/biz/sonic-drive-in-durant...            16
# 15  https://www.yelp.com/biz/sonic-drive-in-calera...            16
#
#                                            categories  rating  \
# 0          [{'alias': 'mexican', 'title': 'Mexican'}]     4.5
# 1   [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     4.5
# 2          [{'alias': 'mexican', 'title': 'Mexican'}]     4.0
# 3          [{'alias': 'mexican', 'title': 'Mexican'}]     3.0
# 4          [{'alias': 'mexican', 'title': 'Mexican'}]     2.5
# 5   [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     3.5
# 6          [{'alias': 'mexican', 'title': 'Mexican'}]     4.0
# 7   [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...     2.0
# 8          [{'alias': 'mexican', 'title': 'Mexican'}]     3.0
# 9   [{'alias': 'donuts', 'title': 'Donuts'}, {'ali...     5.0
# 10  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.5
# 11         [{'alias': 'mexican', 'title': 'Mexican'}]     3.5
# 12             [{'alias': 'cafes', 'title': 'Cafes'}]     3.0
# 13  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...     2.0
# 14  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     2.0
# 15  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...     1.5
#
#                                           coordinates transactions price  \
# 0   {'latitude': 34.0064621463552, 'longitude': -9...           []     $
# 1   {'latitude': 33.9877463, 'longitude': -96.3868...           []    $$
# 2   {'latitude': 33.9969991, 'longitude': -96.3743...           []   NaN
# 3   {'latitude': 34.0011516015915, 'longitude': -9...           []     $
# 4   {'latitude': 33.993478579514935, 'longitude': ...           []     $
# 5   {'latitude': 33.9943084716797, 'longitude': -9...           []    $$
# 6   {'latitude': 33.9988284, 'longitude': -96.4073...           []   NaN
# 7      {'latitude': 33.99947, 'longitude': -96.40599}           []     $
# 8   {'latitude': 33.9384640511098, 'longitude': -9...           []     $
# 9   {'latitude': 34.0056807, 'longitude': -96.4054...           []   NaN
# 10   {'latitude': 33.998253, 'longitude': -96.409073}     [pickup]    $$
# 11  {'latitude': 33.9988187, 'longitude': -96.373228}           []     $
# 12   {'latitude': 33.951446, 'longitude': -96.413891}           []    $$
# 13  {'latitude': 34.00110134174037, 'longitude': -...           []   NaN
# 14  {'latitude': 33.9986944529491, 'longitude': -9...           []   NaN
# 15  {'latitude': 33.9388265, 'longitude': -96.4226...           []     $
#
#                                              location         phone  \
# 0   {'address1': '1255 N Washington Ave', 'address...  +15807458114
# 1   {'address1': '510 S 9th Ave', 'address2': '', ...  +15809200915
# 2   {'address1': '729 N 1st St', 'address2': None,...  +15807458034
# 3   {'address1': '420 University Pl', 'address2': ...  +15809200162
# 4   {'address1': '324 N 1st Ave', 'address2': '', ...  +15809202820
# 5   {'address1': '1202 W Main St', 'address2': '',...  +15809242945
# 6   {'address1': '2430 W Main St', 'address2': '',...  +15809200162
# 7   {'address1': '206 Westside Dr', 'address2': ''...  +15809200242
# 8   {'address1': '703 S Service Rd', 'address2': N...  +15804344090
# 9   {'address1': '2836 W University Blvd', 'addres...  +15809209190
# 10  {'address1': '2501 W Main St', 'address2': '',...  +15809201777
# 11  {'address1': '902 N 1st Ave', 'address2': '', ...  +15809201526
# 12  {'address1': '4216 S Hwy 69/75', 'address2': '...  +15809200160
# 13  {'address1': '1111 N First St', 'address2': ''...  +15809245050
# 14  {'address1': '3619 West Main St', 'address2': ...  +15809202206
# 15  {'address1': '713 N Service Rd', 'address2': N...  +15809317777
#
#      display_phone     distance
# 0   (580) 745-8114   546.357781
# 1   (580) 920-0915  2656.926781
# 2   (580) 745-8034  2310.700387
# 3   (580) 920-0162  1877.349885
# 4   (580) 920-2820  2577.727766
# 5   (580) 924-2945  1898.995916
# 6   (580) 920-0162  1849.415729
# 7   (580) 920-0242  1738.332510
# 8   (580) 434-4090  8523.548219
# 9   (580) 920-9190  1268.272335
# 10  (580) 920-1777  2032.758120
# 11  (580) 920-1526  2302.247131
# 12  (580) 920-0160  2103.521274
# 13  (580) 924-5050  2170.754640
# 14  (580) 920-2206  2200.980919
# 15  (580) 931-7777  8476.376360

# %%
# Display the length of businesses per page (max is 20)
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 16

# %%
# Create variable to calculate total number of pages needed for results
n_pages = math.ceil((results['total'])/ results_per_page)
n_pages
# Out:
# 1

# %%
# Create loop for API call results
for i in tqdm_notebook(range(1, n_pages+1)):
    try:
        time.sleep(.2)
        with open(JSON_FILE, 'r') as f:
            previous_results = json.load(f)
            
        n_results = len(previous_results)
        results = yelp_api.search_query(location=location, term=term,
                                   offset=n_results+1)
        
        previous_results.extend(results['businesses'])
        
        with open(JSON_FILE, 'w') as f:
            json.dump(previous_results, f)
         
    except Exception as e:
        print('[!] ERROR', e)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# Open the Final JSON File with Pandas
df = pd.read_json(JSON_FILE)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             15 non-null     object
#  1   alias          15 non-null     object
#  2   name           15 non-null     object
#  3   image_url      15 non-null     object
#  4   is_closed      15 non-null     bool
#  5   url            15 non-null     object
#  6   review_count   15 non-null     int64
#  7   categories     15 non-null     object
#  8   rating         15 non-null     float64
#  9   coordinates    15 non-null     object
#  10  transactions   15 non-null     object
#  11  price          10 non-null     object
#  12  location       15 non-null     object
#  13  phone          15 non-null     int64
#  14  display_phone  15 non-null     object
#  15  distance       15 non-null     float64
# dtypes: bool(1), float64(2), int64(2), object(11)
# memory usage: 1.9+ KB
